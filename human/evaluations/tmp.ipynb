# %%
import json
def get_json_structure(json_data, parent_key="", structure=None, level=0):
    """递归提取JSON嵌套结构，记录每个key的父key和层级"""
    if structure is None:
        structure = []  # 存储结构：每个元素是 (层级, 父key, 当前key)
    
    indent = "  " * level  # 用缩进表示层级（视觉更清晰）
    
    if isinstance(json_data, dict):  # 字典结构（键值对）
        for key, value in json_data.items():
            current_key_path = f"{parent_key}→{key}" if parent_key else key  # 记录完整路径（比如 task→question→content）
            structure.append((level, parent_key, key, current_key_path))  # 存储层级、父key、当前key、完整路径
            # 递归处理子层级
            get_json_structure(value, parent_key=key, structure=structure, level=level+1)
    elif isinstance(json_data, list):  # 列表结构（数组）
        # 列表本身无key，记录列表的父key和类型
        list_note = f"[列表] 元素类型：{type(json_data[0]).__name__}" if json_data else "[空列表]"
        structure.append((level, parent_key, list_note, f"{parent_key}→{list_note}"))
        # 递归处理列表中的第一个元素（默认列表元素结构一致，如需遍历所有元素可修改）
        if json_data and (isinstance(json_data[0], dict) or isinstance(json_data[0], list)):
            get_json_structure(json_data[0], parent_key=parent_key, structure=structure, level=level+1)
    
    return structure

# %%
with open('./RAG.json', "r", encoding="utf-8") as f:
    data = json.load(f)
structure = get_json_structure(data)

# %%
 
# 输出结构化报告
print("JSON嵌套结构报告（层级→父key→当前key→完整路径）：")
print("=" * 80)
for level, parent, key, full_path in structure:
    indent = "  " * level  # 层级缩进
    print(f"{indent}层级{level} | 父key：{parent or '无'} | 当前key：{key} | 完整路径：{full_path}")
print("=" * 80)

# 额外生成：按完整路径排序的key列表（方便查找）
print("\n按完整路径排序的所有key（含嵌套关系）：")
print("-" * 50)
for _, _, _, full_path in sorted(structure, key=lambda x: x[3]):
    print(full_path)
# Out:
# JSON嵌套结构报告（层级→父key→当前key→完整路径）：
# ================================================================================
# 层级0 | 父key：无 | 当前key：name | 完整路径：name
# 层级0 | 父key：无 | 当前key：models | 完整路径：models
#   层级1 | 父key：models | 当前key：[列表] 元素类型：dict | 完整路径：models→[列表] 元素类型：dict
#     层级2 | 父key：models | 当前key：model_id | 完整路径：models→model_id
#     层级2 | 父key：models | 当前key：name | 完整路径：models→name
#     层级2 | 父key：models | 当前key：owner | 完整路径：models→owner
# 层级0 | 父key：无 | 当前key：metrics | 完整路径：metrics
#   层级1 | 父key：metrics | 当前key：[列表] 元素类型：dict | 完整路径：metrics→[列表] 元素类型：dict
#     层级2 | 父key：metrics | 当前key：name | 完整路径：metrics→name
#     层级2 | 父key：metrics | 当前key：display_name | 完整路径：metrics→display_name
#     层级2 | 父key：metrics | 当前key：description | 完整路径：metrics→description
#     层级2 | 父key：metrics | 当前key：author | 完整路径：metrics→author
#     层级2 | 父key：metrics | 当前key：type | 完整路径：metrics→type
#     层级2 | 父key：metrics | 当前key：aggregator | 完整路径：metrics→aggregator
#     层级2 | 父key：metrics | 当前key：range | 完整路径：metrics→range
#       层级3 | 父key：range | 当前key：[列表] 元素类型：int | 完整路径：range→[列表] 元素类型：int
# 层级0 | 父key：无 | 当前key：documents | 完整路径：documents
#   层级1 | 父key：documents | 当前key：[列表] 元素类型：dict | 完整路径：documents→[列表] 元素类型：dict
#     层级2 | 父key：documents | 当前key：document_id | 完整路径：documents→document_id
#     层级2 | 父key：documents | 当前key：text | 完整路径：documents→text
#     层级2 | 父key：documents | 当前key：title | 完整路径：documents→title
# 层级0 | 父key：无 | 当前key：tasks | 完整路径：tasks
#   层级1 | 父key：tasks | 当前key：[列表] 元素类型：dict | 完整路径：tasks→[列表] 元素类型：dict
#     层级2 | 父key：tasks | 当前key：task_id | 完整路径：tasks→task_id
#     层级2 | 父key：tasks | 当前key：task_type | 完整路径：tasks→task_type
#     层级2 | 父key：tasks | 当前key：input | 完整路径：tasks→input
#       层级3 | 父key：input | 当前key：[列表] 元素类型：dict | 完整路径：input→[列表] 元素类型：dict
#         层级4 | 父key：input | 当前key：speaker | 完整路径：input→speaker
#         层级4 | 父key：input | 当前key：text | 完整路径：input→text
#     层级2 | 父key：tasks | 当前key：contexts | 完整路径：tasks→contexts
#       层级3 | 父key：contexts | 当前key：[列表] 元素类型：dict | 完整路径：contexts→[列表] 元素类型：dict
#         层级4 | 父key：contexts | 当前key：document_id | 完整路径：contexts→document_id
#     层级2 | 父key：tasks | 当前key：targets | 完整路径：tasks→targets
#       层级3 | 父key：targets | 当前key：[列表] 元素类型：dict | 完整路径：targets→[列表] 元素类型：dict
#         层级4 | 父key：targets | 当前key：speaker | 完整路径：targets→speaker
#         层级4 | 父key：targets | 当前key：text | 完整路径：targets→text
#     层级2 | 父key：tasks | 当前key：annotations | 完整路径：tasks→annotations
#       层级3 | 父key：annotations | 当前key：context_relevance | 完整路径：annotations→context_relevance
#         层级4 | 父key：context_relevance | 当前key：system | 完整路径：context_relevance→system
#           层级5 | 父key：system | 当前key：[空列表] | 完整路径：system→[空列表]
#     层级2 | 父key：tasks | 当前key：Question Type | 完整路径：tasks→Question Type
#       层级3 | 父key：Question Type | 当前key：[列表] 元素类型：str | 完整路径：Question Type→[列表] 元素类型：str
#     层级2 | 父key：tasks | 当前key：Multi-Turn | 完整路径：tasks→Multi-Turn
#       层级3 | 父key：Multi-Turn | 当前key：[空列表] | 完整路径：Multi-Turn→[空列表]
#     层级2 | 父key：tasks | 当前key：# Relevant Passages | 完整路径：tasks→# Relevant Passages
#     层级2 | 父key：tasks | 当前key：# Retrieved Reference Passages | 完整路径：tasks→# Retrieved Reference Passages
#     层级2 | 父key：tasks | 当前key：Retriever Performance Characteristics | 完整路径：tasks→Retriever Performance Characteristics
#     层级2 | 父key：tasks | 当前key：Answerability | 完整路径：tasks→Answerability
#       层级3 | 父key：Answerability | 当前key：[列表] 元素类型：str | 完整路径：Answerability→[列表] 元素类型：str
#     层级2 | 父key：tasks | 当前key：Turn | 完整路径：tasks→Turn
#     层级2 | 父key：tasks | 当前key：Collection | 完整路径：tasks→Collection
# 层级0 | 父key：无 | 当前key：evaluations | 完整路径：evaluations
#   层级1 | 父key：evaluations | 当前key：[列表] 元素类型：dict | 完整路径：evaluations→[列表] 元素类型：dict
#     层级2 | 父key：evaluations | 当前key：task_id | 完整路径：evaluations→task_id
#     层级2 | 父key：evaluations | 当前key：model_id | 完整路径：evaluations→model_id
#     层级2 | 父key：evaluations | 当前key：model_response | 完整路径：evaluations→model_response
#     层级2 | 父key：evaluations | 当前key：annotations | 完整路径：evaluations→annotations
#       层级3 | 父key：annotations | 当前key：RougeL | 完整路径：annotations→RougeL
#         层级4 | 父key：RougeL | 当前key：system | 完整路径：RougeL→system
#           层级5 | 父key：system | 当前key：value | 完整路径：system→value
#       层级3 | 父key：annotations | 当前key：Bert-Rec | 完整路径：annotations→Bert-Rec
#         层级4 | 父key：Bert-Rec | 当前key：system | 完整路径：Bert-Rec→system
#           层级5 | 父key：system | 当前key：value | 完整路径：system→value
#       层级3 | 父key：annotations | 当前key：Bert-KPrec | 完整路径：annotations→Bert-KPrec
#         层级4 | 父key：Bert-KPrec | 当前key：system | 完整路径：Bert-KPrec→system
#           层级5 | 父key：system | 当前key：value | 完整路径：system→value
#       层级3 | 父key：annotations | 当前key：conditional_idk | 完整路径：annotations→conditional_idk
#         层级4 | 父key：conditional_idk | 当前key：composite | 完整路径：conditional_idk→composite
#           层级5 | 父key：composite | 当前key：value | 完整路径：composite→value
#       层级3 | 父key：annotations | 当前key：rl_f | 完整路径：annotations→rl_f
#         层级4 | 父key：rl_f | 当前key：composite | 完整路径：rl_f→composite
#           层级5 | 父key：composite | 当前key：value | 完整路径：composite→value
#       层级3 | 父key：annotations | 当前key：rb_llm | 完整路径：annotations→rb_llm
#         层级4 | 父key：rb_llm | 当前key：composite | 完整路径：rb_llm→composite
#           层级5 | 父key：composite | 当前key：value | 完整路径：composite→value
#       层级3 | 父key：annotations | 当前key：rb_agg | 完整路径：annotations→rb_agg
#         层级4 | 父key：rb_agg | 当前key：composite | 完整路径：rb_agg→composite
#           层级5 | 父key：composite | 当前key：value | 完整路径：composite→value
# 层级0 | 父key：无 | 当前key：filters | 完整路径：filters
#   层级1 | 父key：filters | 当前key：[列表] 元素类型：str | 完整路径：filters→[列表] 元素类型：str
# ================================================================================
#
# 按完整路径排序的所有key（含嵌套关系）：
# --------------------------------------------------
# Answerability→[列表] 元素类型：str
# Bert-KPrec→system
# Bert-Rec→system
# Multi-Turn→[空列表]
# Question Type→[列表] 元素类型：str
# RougeL→system
# annotations→Bert-KPrec
# annotations→Bert-Rec
# annotations→RougeL
# annotations→conditional_idk
# annotations→context_relevance
# annotations→rb_agg
# annotations→rb_llm
# annotations→rl_f
# composite→value
# composite→value
# composite→value
# composite→value
# conditional_idk→composite
# context_relevance→system
# contexts→[列表] 元素类型：dict
# contexts→document_id
# documents
# documents→[列表] 元素类型：dict
# documents→document_id
# documents→text
# documents→title
# evaluations
# evaluations→[列表] 元素类型：dict
# evaluations→annotations
# evaluations→model_id
# evaluations→model_response
# evaluations→task_id
# filters
# filters→[列表] 元素类型：str
# input→[列表] 元素类型：dict
# input→speaker
# input→text
# metrics
# metrics→[列表] 元素类型：dict
# metrics→aggregator
# metrics→author
# metrics→description
# metrics→display_name
# metrics→name
# metrics→range
# metrics→type
# models
# models→[列表] 元素类型：dict
# models→model_id
# models→name
# models→owner
# name
# range→[列表] 元素类型：int
# rb_agg→composite
# rb_llm→composite
# rl_f→composite
# system→[空列表]
# system→value
# system→value
# system→value
# targets→[列表] 元素类型：dict
# targets→speaker
# targets→text
# tasks
# tasks→# Relevant Passages
# tasks→# Retrieved Reference Passages
# tasks→Answerability
# tasks→Collection
# tasks→Multi-Turn
# tasks→Question Type
# tasks→Retriever Performance Characteristics
# tasks→Turn
# tasks→[列表] 元素类型：dict
# tasks→annotations
# tasks→contexts
# tasks→input
# tasks→targets
# tasks→task_id
# tasks→task_type
